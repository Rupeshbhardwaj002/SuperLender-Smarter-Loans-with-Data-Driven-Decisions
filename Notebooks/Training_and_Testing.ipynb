# %% [markdown]
# Here we imported pandas as pd libraray. And after this we downloaded our required datasets which we uploaded on github.

# %%
import pandas as pd
train_previous = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/trainprevious./trainprevloans.csv')
train_perf = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/trainperf.csv')
train_demo = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/traindemographics.csv')
test_previous = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/testpreviousloans/testprevloans.csv')
test_perf = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/testperf.csv')
test_demo = pd.read_csv('https://raw.githubusercontent.com/Rupeshbhardwaj002/SuperLender-Smarter-Loans-with-Data-Driven-Decisions/refs/heads/main/data/testdemographics.csv')

# %% [markdown]
# Here we printed head just to check.

# %%
train_previous.head()
# Out:
#                          customerid  systemloanid  loannumber  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049     301682320           2
# 1  8a2a81a74ce8c05d014cfb32a0da1049     301883808           9
# 2  8a2a81a74ce8c05d014cfb32a0da1049     301831714           8
# 3  8a8588f35438fe12015444567666018e     301861541           5
# 4  8a85890754145ace015429211b513e16     301941754           2
#
#                  approveddate                creationdate  loanamount  \
# 0  2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000     10000.0
# 1  2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000     10000.0
# 2  2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000     20000.0
# 3  2017-04-09 18:25:55.000000  2017-04-09 17:25:42.000000     10000.0
# 4  2017-06-17 09:29:57.000000  2017-06-17 08:29:50.000000     10000.0
#
#    totaldue  termdays                  closeddate referredby  \
# 0   13000.0        30  2016-09-01 16:06:48.000000        NaN
# ...

# %% [markdown]
# Now we mered our dataset in one file from the other 3 training files that includes train previous, train demographics and train perf they all contains a unique key customer id which we used to connect them.

# %%
temp_data = pd.merge(train_previous, train_perf, on='customerid',how='left')
df = pd.merge(temp_data, train_demo, on='customerid', how='left')
# print(df.shape)
df.head()
# Out:
#                          customerid  systemloanid_x  loannumber_x  \
# 0  8a2a81a74ce8c05d014cfb32a0da1049       301682320             2
# 1  8a2a81a74ce8c05d014cfb32a0da1049       301883808             9
# 2  8a2a81a74ce8c05d014cfb32a0da1049       301831714             8
# 3  8a8588f35438fe12015444567666018e       301861541             5
# 4  8a85890754145ace015429211b513e16       301941754             2
#
#                approveddate_x              creationdate_x  loanamount_x  \
# 0  2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000       10000.0
# 1  2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000       10000.0
# 2  2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000       20000.0
# 3  2017-04-09 18:25:55.000000  2017-04-09 17:25:42.000000       10000.0
# 4  2017-06-17 09:29:57.000000  2017-06-17 08:29:50.000000       10000.0
#
#    totaldue_x  termdays_x                  closeddate referredby_x  ...  \
# ...

# %% [markdown]
# Here we merged them all in one file df.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18203 entries, 0 to 18202
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  18203 non-null  object
#  1   systemloanid_x              18203 non-null  int64
#  2   loannumber_x                18203 non-null  int64
#  3   approveddate_x              18203 non-null  object
#  4   creationdate_x              18203 non-null  object
#  5   loanamount_x                18203 non-null  float64
#  6   totaldue_x                  18203 non-null  float64
#  7   termdays_x                  18203 non-null  int64
#  8   closeddate                  18203 non-null  object
#  9   referredby_x                1028 non-null   object
#  10  firstduedate                18203 non-null  object
#  11  firstrepaiddate             18203 non-null  object
#  12  systemloanid_y              18203 non-null  int64
# ...

# %% [markdown]
# We have drroped column  df['bank_branch_clients'] because a lot of null values in this column.

# %%
df = df.drop(['bank_branch_clients'], axis=1)
print(df.columns)
# Out:
# Index(['customerid', 'systemloanid_x', 'loannumber_x', 'approveddate_x',
#        'creationdate_x', 'loanamount_x', 'totaldue_x', 'termdays_x',
#        'closeddate', 'referredby_x', 'firstduedate', 'firstrepaiddate',
#        'systemloanid_y', 'loannumber_y', 'approveddate_y', 'creationdate_y',
#        'loanamount_y', 'totaldue_y', 'termdays_y', 'referredby_y',
#        'good_bad_flag', 'birthdate', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'employment_status_clients',
#        'level_of_education_clients'],
#       dtype='object')

# %%
df['approveddate_x'] = pd.to_datetime(df['approveddate_x'], errors='coerce')
df['birthdate'] = pd.to_datetime(df['birthdate'], errors='coerce')
df['creationdate_x'] = pd.to_datetime(df['creationdate_x'], errors='coerce')
df['closeddate'] = pd.to_datetime(df['closeddate'], errors='coerce')

# Age at time of loan
df['age'] = (df['approveddate_x'] - df['birthdate']).dt.days // 365

# Loan duration
df['loan_duration_days'] = (df['closeddate'] - df['approveddate_x']).dt.days

# Time since account creation
df['days_since_creation'] = (pd.Timestamp.now() - df['creationdate_x']).dt.days

# Month and weekday of approval
df['approval_month'] = df['approveddate_x'].dt.month
df['approval_weekday'] = df['approveddate_x'].dt.weekday

df.drop(['approveddate_x', 'birthdate', 'creationdate_x', 'closeddate'], axis=1, inplace=True)

# %% [markdown]
# USING LOOP FOR ENCODING BECAUSE A LOT OF WORK INCREASE IF WE MANUALLY DO EVRY FEATURE SPECIALLY IN MORE LARGE DATASETS.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in df.columns:
  if(df[col].dtype == object):
    df[col] = encoder.fit_transform(df[col])

# %% [markdown]
# So our dataset has a lot off fetures that is why we are using correlation matrix to find out the least coreelated feature so we can drop them

# %% [markdown]
# You can see that here are the least coorelated fetures termdays_y                    0.012122,
# approval_month                0.000446,
# approval_weekday             -0.009591,
# latitude_gps                 -0.009620,

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.show()

# %%
coorelated_features = corr['good_bad_flag'].sort_values(ascending = False)
print(coorelated_features)
# Out:
# good_bad_flag                 1.000000
# loanamount_y                  0.108371
# totaldue_y                    0.097243
# loannumber_y                  0.084015
# loanamount_x                  0.069605
# totaldue_x                    0.067799
# age                           0.055528
# loannumber_x                  0.055343
# days_since_creation           0.024047
# referredby_y                  0.023436
# referredby_x                  0.023436
# termdays_x                    0.023006
# systemloanid_y                0.019352
# approveddate_y                0.017334
# creationdate_y                0.017321
# approval_month               -0.001012
# approval_weekday             -0.004146
# latitude_gps                 -0.009620
# bank_name_clients            -0.011931
# longitude_gps                -0.013174
# level_of_education_clients   -0.015135
# termdays_y                   -0.016092
# firstduedate                 -0.022507
# systemloanid_x               -0.024516
# ...

# %% [markdown]
# here we have drooped some columns and used label encoder also in some columns to convert them in numeric form from string or characters.

# %%
df.head()
# Out:
#    customerid  systemloanid_x  loannumber_x  loanamount_x  totaldue_x  \
# 0           6       301682320             2       10000.0     13000.0
# 1           6       301883808             9       10000.0     13000.0
# 2           6       301831714             8       20000.0     23800.0
# 3         140       301861541             5       10000.0     11500.0
# 4         204       301941754             2       10000.0     11500.0
#
#    termdays_x  referredby_x  firstduedate  firstrepaiddate  systemloanid_y  \
# 0          30           521           122             1432       301994762
# 1          30           521           302            11125       301994762
# 2          30           521           264             8969       301994762
# 3          15           521           278             8686       301966580
# 4          15           521           326            16491       301999343
#
#    ...  longitude_gps  latitude_gps  bank_name_clients  \
# ...

# %%
df = df.fillna(0)

# %%
print(df.columns)
# Out:
# Index(['customerid', 'systemloanid_x', 'loannumber_x', 'loanamount_x',
#        'totaldue_x', 'termdays_x', 'referredby_x', 'firstduedate',
#        'firstrepaiddate', 'systemloanid_y', 'loannumber_y', 'approveddate_y',
#        'creationdate_y', 'loanamount_y', 'totaldue_y', 'termdays_y',
#        'referredby_y', 'good_bad_flag', 'bank_account_type', 'longitude_gps',
#        'latitude_gps', 'bank_name_clients', 'employment_status_clients',
#        'level_of_education_clients', 'age', 'loan_duration_days',
#        'days_since_creation', 'approval_month', 'approval_weekday'],
#       dtype='object')

# %% [markdown]
# NOW WE WILL DIVIDE OUR DATASET IN X AND Y . AS WE KNOW TEST DATA ONLY CONATAINS INPUTS HENCE IT DOESN'T NEEDS TO BE ANYTHING CHANGED. and we will also drop the columns here that has low coorelation that we find out before.

# %%
X = df[['loannumber_x', 'loanamount_x',
       'totaldue_x', 'termdays_x', 'referredby_x', 'firstduedate',
       'firstrepaiddate', 'systemloanid_y', 'loannumber_y', 'approveddate_y',
       'creationdate_y', 'loanamount_y', 'totaldue_y', 'termdays_y',
       'referredby_y', 'bank_account_type', 'longitude_gps', 'bank_name_clients',
        'employment_status_clients','level_of_education_clients', 'age',
        'loan_duration_days','days_since_creation']]
Y = df['good_bad_flag']

# %%
X.head()
# Out:
#    loannumber_x  loanamount_x  totaldue_x  termdays_x  referredby_x  \
# 0             2       10000.0     13000.0          30           521
# 1             9       10000.0     13000.0          30           521
# 2             8       20000.0     23800.0          30           521
# 3             5       10000.0     11500.0          15           521
# 4             2       10000.0     11500.0          15           521
#
#    firstduedate  firstrepaiddate  systemloanid_y  loannumber_y  \
# 0           122             1432       301994762            12
# 1           302            11125       301994762            12
# 2           264             8969       301994762            12
# 3           278             8686       301966580             7
# 4           326            16491       301999343             3
#
#    approveddate_y  ...  termdays_y  referredby_y  bank_account_type  \
# 0            3388  ...          30           521                  1
# ...

# %% [markdown]
# we are doing standard scaling because in some of the feature there is a huge diffrence.

# %%
from sklearn.preprocessing import StandardScaler
d = StandardScaler()
X = d.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (12742, 23)
# (12742,)
# (5461, 23)
# (5461,)

# %% [markdown]
# First we will try with the logistic regression because it is simple and fast for classification tasks

# %%
from sklearn.linear_model import LogisticRegression
model =LogisticRegression(max_iter=2500)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=2500)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import recall_score, f1_score, roc_auc_score, accuracy_score, precision_score

print("Accuracy:", accuracy_score(Y_test, y_pred))
print("Precison:", precision_score(Y_test, y_pred))
print("Recall:", recall_score(Y_test, y_pred))
print("F1 Score:", f1_score(Y_test, y_pred))
print("ROC AUC:", roc_auc_score(Y_test, model.predict_proba(X_test)[:, 1]))
# Out:
# Accuracy: 0.810657388756638
# Precison: 0.8112619222303742
# Recall: 0.9988708220415538
# F1 Score: 0.8953441295546559
# ROC AUC: 0.6345398594353805

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(Y_test, y_pred)

print("Confusion Matrix:")

class_names = ['Class A', 'Class B']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Oranges)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:

# %% [markdown]
# The metrices result is not like our expectations specially ROC and AUC score which is near to 0.5 which means our model is weak in making diffrence between bad and good loans

# %%
from sklearn.metrics import roc_curve, precision_recall_curve
import matplotlib.pyplot as plt

y_scores = model.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(Y_test, y_scores)
plt.plot(fpr, tpr)
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %% [markdown]
# Now we will use boosting classifier - random forest its is a ensemble method technique. it is a strong learner made from many weak leanere(Decison tree) it minimizes the variance and bias but its little slow because of training in sequentail we are also using gridsearch cv to find best result giving parameters of our random forest.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}
grid_search = GridSearchCV(estimator=rf,
                           param_grid=param_grid,
                           cv=5,
                           scoring='roc_auc',
                           n_jobs=-1,
                           verbose=2)


grid_search.fit(X_train, Y_train)
print("Best:", grid_search.best_params_)
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %% [markdown]
# Here our metirces are metting our exxpectations. Which means our model is working fine hence we will finalize random forest if we want we can use stacking also because it is more powerful than boosting or other classification techniques.

# %%
print("Accuracy:", accuracy_score(Y_test, y_pred))
print("Precison:", precision_score(Y_test, y_pred))
print("Recall:", recall_score(Y_test, y_pred))
print("F1 Score:", f1_score(Y_test, y_pred))
print("ROC AUC:", roc_auc_score(Y_test, best_rf.predict_proba(X_test)[:, 1]))
# Out:
# Accuracy: 0.8987364951474089
# Precison: 0.8942014242115972
# Recall: 0.9925474254742548
# F1 Score: 0.9408113025794712
# ROC AUC: 0.9602718465874559

# %%
cm = confusion_matrix(Y_test, y_pred)

print("Confusion Matrix:")

class_names = ['Class A', 'Class B']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Oranges)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:

# %%
import xgboost as xgb


# XGBoost model

xgb_model = xgb.XGBClassifier(
    max_depth=6,
    learning_rate=0.1,
    n_estimators=200,
    objective='binary:logistic',
    eval_metric='auc',
    use_label_encoder=False,
    random_state=42
)

xgb_model.fit(X_train, Y_train)
xgb_pred = xgb_model.predict(X_test)


print("Accuracy:", accuracy_score(Y_test, xgb_pred))
print("Precison:", precision_score(Y_test, xgb_pred))
print("Recall:", recall_score(Y_test, xgb_pred))
print("F1 Score:", f1_score(Y_test, xgb_pred))
print("ROC AUC:", roc_auc_score(Y_test, xgb_model.predict_proba(X_test)[:, 1]))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [16:52:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.9013001281816517
# Precison: 0.8983814792050809
# Recall: 0.9902890695573623
# F1 Score: 0.942099043935976
# ROC AUC: 0.9477354571061037

# %%
cm = confusion_matrix(Y_test, xgb_pred)

print("Confusion Matrix:")

class_names = ['Class A', 'Class B']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Oranges)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:

# %%
# !pip install catboost

# %%
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from catboost import CatBoostClassifier
# Define base learners
base_learners = [
    ('rf', RandomForestClassifier(n_estimators=100, max_depth=20, random_state=42)),
    ('xgb', xgb.XGBClassifier(max_depth=6, learning_rate=0.1, n_estimators=100, use_label_encoder=False, eval_metric='auc', random_state=42)),
    ('cat', CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6, verbose=0, random_seed=42))
]


meta_learner = LogisticRegression()

# Create stacking classifier
stack_model = StackingClassifier(estimators=base_learners, final_estimator=meta_learner, cv=5)

# Fit stack model on training partition
stack_model.fit(X_train, Y_train)

# Validate
y_pred = stack_model.predict(X_test)
print("Validation Accuracy:", accuracy_score(Y_test, y_pred))

print("Accuracy:", accuracy_score(Y_test, y_pred))
print("Precison:", precision_score(Y_test, y_pred))
print("Recall:", recall_score(Y_test, y_pred))
print("F1 Score:", f1_score(Y_test, y_pred))
print("ROC AUC:", roc_auc_score(Y_test, stack_model.predict_proba(X_test)[:, 1]))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [16:52:20] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [16:52:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [16:52:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Validation Accuracy: 0.9216260758102911
# Accuracy: 0.9216260758102911
# Precison: 0.9302925989672978
# Recall: 0.976513098464318
# F1 Score: 0.9528426619656236
# ROC AUC: 0.9571620708139963

# %%
cm = confusion_matrix(Y_test, y_pred)

print("Confusion Matrix:")

class_names = ['Class A', 'Class B']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Oranges)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
